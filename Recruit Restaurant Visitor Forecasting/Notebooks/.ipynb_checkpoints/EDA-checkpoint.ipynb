# %%
mlbyte
# Out:
#  _______        ______  __   __ _______ _______
#  |  |  | |      |_____]   \_/      |    |______
#  |  |  | |_____ |_____]    |       |    |______
#
#
#                          ~ by Mohammad Shahebaz
#
# Printing versions of libraries loaded
# Sklearn version: 0.19.1
# Pandas version:  0.20.1
# Numpy version: 1.13.3
# Matplotlib version: 2.1.0
# Seaborn version: 0.8.0

# %%
data = {
    'tra': pd.read_csv('../input/air_visit_data.csv'),
    'as': pd.read_csv('../input/air_store_info.csv'),
    'hs': pd.read_csv('../input/hpg_store_info.csv'),
    'ar': pd.read_csv('../input/air_reserve.csv'),
    'hr': pd.read_csv('../input/hpg_reserve.csv'),
    'id': pd.read_csv('../input/store_id_relation.csv'),
    'tes': pd.read_csv('../input/sample_submission.csv'),
    'hol': pd.read_csv('../input/date_info.csv').rename(columns={'calendar_date':'visit_date'})
    }

# %% [markdown]
# ### **Air visit data**

# %%
air = pd.merge(data['as'], data['tra'])

# %%
data['tra'].head()
# Out:
#            air_store_id  visit_date  visitors
# 0  air_ba937bf13d40fb24  2016-01-13        25
# 1  air_ba937bf13d40fb24  2016-01-14        32
# 2  air_ba937bf13d40fb24  2016-01-15        29
# 3  air_ba937bf13d40fb24  2016-01-16        22
# 4  air_ba937bf13d40fb24  2016-01-18         6

# %%
data['tra'].describe()
# Out:
#             visitors
# count  252108.000000
# mean       20.973761
# std        16.757007
# min         1.000000
# 25%         9.000000
# 50%        17.000000
# 75%        29.000000
# max       877.000000

# %%
max_logic = data['tra']['visitors'] == data['tra']['visitors'].max()
data['tra'][max_logic]
# Out:
#                air_store_id  visit_date  visitors
# 85314  air_cfdeb326418194ff  2017-03-08       877

# %%
data['tra'].set_index('visit_date',inplace=True)
data['tra'].index = pd.to_datetime(data['tra'].index)

# %%
data['tra'].head()
# Out:
#                     air_store_id  visitors
# visit_date
# 2016-01-13  air_ba937bf13d40fb24        25
# 2016-01-14  air_ba937bf13d40fb24        32
# 2016-01-15  air_ba937bf13d40fb24        29
# 2016-01-16  air_ba937bf13d40fb24        22
# 2016-01-18  air_ba937bf13d40fb24         6

# %% [markdown]
# ### **Rolling Mean of Visitors for air data**

# %%
from ggplot import *

# %%
tra_roll = data['tra'].rolling(window=7).mean()
tra_roll.index = pd.to_datetime(tra_roll.index)

# %%
tra_roll.plot(figsize=(15,7))

# %% [markdown]
# ### **Resampling air data**

# %%
data['tra'].resample('W').max().plot(kind='line',figsize=(13,5))
plt.title('Weekly Max Visitors')
# Out:
# Text(0.5,1,u'Weekly Max Visitors')

# %%
data['tra'].resample('W').mean().plot(kind='line',figsize=(13,5),color='b')
plt.title('Weekly Mean Visitors')
# Out:
# Text(0.5,1,u'Weekly Mean Visitors')

# %%
data['tra'].resample('W').min().plot(kind='line',figsize=(13,5),color='g')
plt.title('Weekly Min Visitors')
# Out:
# Text(0.5,1,u'Weekly Min Visitors')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data['tra']['visitors'], freq=100)

# %%
fig = plt.figure(figsize=(13,5))  
fig = decomposition.plot() 
fig.set_size_inches(12, 10)

# %% [markdown]
# ### **Air store data**

# %%
air.head()
# Out:
#            air_store_id  air_genre_name                 air_area_name  \
# 0  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 2  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 3  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 4  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
#
#     latitude   longitude  visit_date  visitors
# 0  34.695124  135.197852  2016-07-01        18
# 1  34.695124  135.197852  2016-07-02        37
# 2  34.695124  135.197852  2016-07-03        20
# 3  34.695124  135.197852  2016-07-04        16
# 4  34.695124  135.197852  2016-07-05        15
